# %%
import numpy as np
from skimage import io, color
import matplotlib.pyplot as plt

# %% [markdown]
# https://www.ic.unicamp.br/~helio/disciplinas/MO443/trabalho2.pdf

# %% [markdown]
# ## Reading the image

# %%
channel = 2

# %%
img = io.imread("baboon.png")
io.imshow(img) 
io.show()

# %%
img.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ### Converting to CIELab

# %%
lab = color.rgb2hsv(img)
lab.shape
# Out:
# (512, 512, 3)

# %%
#Define the threshold value to define the 0 or 1
# threshold = lab[:,:,channel].max() / 2

# %% [markdown]
# ## Appling the mask

# %%
#Set the luminance channel to be used
luminance = lab[:,:,channel]

#Define the matriz with erro of each pixel
# erro = np.zeros([luminance.shape[0], luminance.shape[1]])

#Output image
# g = luminance.copy()
# g =  np.ones([luminance.shape[0], luminance.shape[1]])

# %%
# lab2 = lab.copy()

# %%
def create_middle_tons(luminance, g, mask, limit=1):
    """
    Loop to apply the middle tons mask in each pixel of the image
    """
    #loop to check all pixels of the image
    for row in range(luminance.shape[0]-limit):
        for collumn in range(luminance.shape[1]-limit):
            if (luminance[row][collumn] * 255) < threshold:
                g[row][collumn] = 0
            else:
                g[row][collumn] = 1

            erro = luminance[row][collumn] - g[row][collumn] * 255

            #Applyig the mask
            luminance[row+1][collumn] += (7/16) * erro
            luminance[row-1][collumn-1] += (3/16) * erro
            luminance[row][collumn+1] += (5/16) * erro
            luminance[row+1][collumn+1] += (1/16) * erro
    return luminance

# %% [markdown]
# ## Mask functions

# %%
def mask_Steinberg(luminance, erro, row, collumn):
    """
    Apply the Floyd e Steinberg in a pixel of the image, and return the luminance and erro;
    """
    luminance[row+1][collumn] += (7/16) * erro
    luminance[row-1][collumn-1] += (3/16) * erro
    luminance[row][collumn+1] += (5/16) * erro
    luminance[row+1][collumn+1] += (1/16) * erro
    
    return luminance

# %% [markdown]
# ## Aplying the masks

# %%
threshold = 128

# %%
def normalize_luminance(luminance):
    
   
    return  (luminance - np.min(luminance)) / (np.max(luminance) - np.min(luminance))

# %%
#Floyd e Steinberg Result
lab_Steinberg = lab.copy()
luminance_Steinberg = luminance.copy()
g_Steinberg = luminance.copy()

luminance_Steinberg = create_middle_tons(luminance.copy(), luminance.copy(), mask_Steinberg)

# first = (luminance_Steinberg * np.min(luminance_Steinberg))
# second = (np.max(luminance_Steinberg) * np.min(luminance_Steinberg))
# lab_Steinberg[:,:,channel] =  first/ second
lab_Steinberg[:,:,channel] = luminance_Steinberg

#Plot the results
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(10, 8))
ax0.imshow(img)
ax1.imshow(color.hsv2rgb(lab_Steinberg))

# io.imshow(img)
# io.show()
# io.imshow(color.hsv2rgb(lab_Steinberg)) 
# io.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(lab_Steinberg)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
Image = np.clip(color.rgb2hsv(lab_Steinberg), 0, 1)
plt.imshow(Image)
# Out:
# F:\stiva\anaconda3\lib\site-packages\skimage\color\colorconv.py:238: RuntimeWarning: divide by zero encountered in true_divide
#   out_s = delta / out_v
